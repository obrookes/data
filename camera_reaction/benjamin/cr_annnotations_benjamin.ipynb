# %%
import os
import pandas as pd
from glob import glob

# %%
# F = staring at the camera/inspecting the camera
# P = No reaction
# A = coming closer to the camera (because the camera was spotted. We can see that the chimpanzee noticed the camera, and they are now
#     getting closer to inspect it)
# R = Moving away from the camera (because the camera was spotted. We can see that the chipmanzee noticed the camera, and they are now
#     going away from it, often quicky as affraid of it)

# %% [markdown]
# #### **North East**

# %%
df_ne = pd.read_csv("DS_North_East/20220406_DSNE_Chimp.txt", delimiter="\t")
print(f"Number of videos: {df_ne.VideoName.nunique()}")
# Out:
# Number of videos: 873

# %%
# Replace lower case p with upper case P
df_ne.Reaction.replace({"p": "P"}, inplace=True)

# %%
def extract_videos_reactions(df, keep_p=False):
    r, no_r, react, no_react = [], [], [], []
    for video in df.VideoName.unique():
        reactions = set(df[df.VideoName == video]["Reaction"])
        # check if A or P or N is in reactions
        if ("A" in reactions) or ("F" in reactions) or ("R" in reactions):
            r.append(video)
            if not keep_p:
                if "P" in reactions:
                    reactions.remove("P")
            react.append(list(reactions))
        else:
            no_r.append(video)
            no_react.append(list(reactions))
    return r, no_r, react, no_react

# %%
# TODO: consider whether excluding P from multilabel is correct...


def create_multilabel_df(r, no_r, react, no_react):
    df = pd.DataFrame({"video": r, "react": react})
    df["inspection"] = df["react"].apply(lambda x: True if "F" in x else False)
    df["attraction"] = df["react"].apply(lambda x: True if "A" in x else False)
    df["avoidance"] = df["react"].apply(lambda x: True if "R" in x else False)
    df["no_reaction"] = False

    tmp = pd.DataFrame(
        {
            "video": no_r,
            "react": no_react,
            "inspection": False,
            "avoidance": False,
            "attraction": False,
            "no_reaction": True,
        }
    ).dropna()

    df = pd.concat([df, tmp])
    to_label = lambda x: ",".join([str(i) for i in x])
    df["label"] = (
        df[df.columns[2:]].astype(int).apply(to_label, axis=1).astype("category")
    )
    df["label"] = df.label.str.split(",")
    df["label"] = df.label.apply(lambda x: [int(i) for i in x])

    return df

# %%
r, no_r, react, no_react = extract_videos_reactions(df=df_ne, keep_p=False)
ne_df = create_multilabel_df(r, no_r, react, no_react)

# %%
ne_df
# Out:
#                                                  video   react  inspection  \
# 0    20200415_101022_Pan troglodytes verus_273137_1...  [F, A]        True
# 1    20200402_071827_Pan troglodytes verus_271696_1...     [F]        True
# 2    20200402_084859_Pan troglodytes verus_271696_1...     [F]        True
# 3    20200325_091743_Pan troglodytes verus_270934_1...  [F, R]        True
# 4    20200330_151611_Pan troglodytes verus_270934_1...     [F]        True
# ..                                                 ...     ...         ...
# 666  20200608_140943_Pan troglodytes verus_268743_1...     [P]       False
# 667  20200522_074814_Pan troglodytes verus_270004_1...     [P]       False
# 668  20200422_155433_Pan troglodytes verus_288938_1...     [P]       False
# 669  20200704_192106_Pan troglodytes verus_285951_1...     [P]       False
# 670  20200420_155023_Pan troglodytes verus_264484_1...     [P]       False
#
#      attraction  avoidance  no_reaction         label
# 0          True      False        False  [1, 1, 0, 0]
# 1         False      False        False  [1, 0, 0, 0]
# 2         False      False        False  [1, 0, 0, 0]
# 3         False       True        False  [1, 0, 1, 0]
# 4         False      False        False  [1, 0, 0, 0]
# ..          ...        ...          ...           ...
# 666       False      False         True  [0, 0, 0, 1]
# 667       False      False         True  [0, 0, 0, 1]
# 668       False      False         True  [0, 0, 0, 1]
# 669       False      False         True  [0, 0, 0, 1]
# 670       False      False         True  [0, 0, 0, 1]
#
# [873 rows x 7 columns]

# %%
ne_df.video = ne_df.video.str.rstrip(" ").str.replace(" ", "_").str.lower()

# %% [markdown]
# #### **North West**

# %%
df_nw = pd.read_csv("DS_North_West/20220331_DSNW_Chimp.txt", delimiter="\t")
print(f"Number of videos: {df_nw.VideoName.nunique()}")
# Out:
# Number of videos: 382

# %%
r, no_r, react, no_react = extract_videos_reactions(df=df_nw, keep_p=False)
nw_df = create_multilabel_df(r, no_r, react, no_react)

# %%
nw_df
# Out:
#                                                  video   react  inspection  \
# 0    20201025_113755_Pan troglodytes verus_250256_1...     [F]        True
# 1    20201027_142211_Pan troglodytes verus_258806_1...     [F]        True
# 2    20201121_111607_Pan troglodytes verus_250256_1...  [F, R]        True
# 3    20201223_110755_Pan troglodytes verus_255956_1...     [F]        True
# 4    20210322_063617_Pan troglodytes verus_246603_1...     [F]        True
# ..                                                 ...     ...         ...
# 316  20210305_114417_Pan troglodytes verus_264506_1...     [P]       False
# 317  20210305_114620_Pan troglodytes verus_264506_1...     [P]       False
# 318  20210305_115136_Pan troglodytes verus_258313_1...     [P]       False
# 319  20210323_104748_Pan troglodytes verus_258313_1...     [P]       False
# 320  20210223_145011_Pan troglodytes verus_263563_1...     [P]       False
#
#      attraction  avoidance  no_reaction         label
# 0         False      False        False  [1, 0, 0, 0]
# 1         False      False        False  [1, 0, 0, 0]
# 2         False       True        False  [1, 0, 1, 0]
# 3         False      False        False  [1, 0, 0, 0]
# 4         False      False        False  [1, 0, 0, 0]
# ..          ...        ...          ...           ...
# 316       False      False         True  [0, 0, 0, 1]
# 317       False      False         True  [0, 0, 0, 1]
# 318       False      False         True  [0, 0, 0, 1]
# 319       False      False         True  [0, 0, 0, 1]
# 320       False      False         True  [0, 0, 0, 1]
#
# [382 rows x 7 columns]

# %%
nw_df.video = (
    nw_df.video.str.rstrip(" ").str.lstrip(" ").str.replace(" ", "_").str.lower()
)

# %%
nw_df
# Out:
#                                                  video   react  inspection  \
# 0    20201025_113755_pan_troglodytes_verus_250256_1...     [F]        True
# 1    20201027_142211_pan_troglodytes_verus_258806_1...     [F]        True
# 2    20201121_111607_pan_troglodytes_verus_250256_1...  [F, R]        True
# 3    20201223_110755_pan_troglodytes_verus_255956_1...     [F]        True
# 4    20210322_063617_pan_troglodytes_verus_246603_1...     [F]        True
# ..                                                 ...     ...         ...
# 316  20210305_114417_pan_troglodytes_verus_264506_1...     [P]       False
# 317  20210305_114620_pan_troglodytes_verus_264506_1...     [P]       False
# 318  20210305_115136_pan_troglodytes_verus_258313_1...     [P]       False
# 319  20210323_104748_pan_troglodytes_verus_258313_1...     [P]       False
# 320  20210223_145011_pan_troglodytes_verus_263563_1...     [P]       False
#
#      attraction  avoidance  no_reaction         label
# 0         False      False        False  [1, 0, 0, 0]
# 1         False      False        False  [1, 0, 0, 0]
# 2         False       True        False  [1, 0, 1, 0]
# 3         False      False        False  [1, 0, 0, 0]
# 4         False      False        False  [1, 0, 0, 0]
# ..          ...        ...          ...           ...
# 316       False      False         True  [0, 0, 0, 1]
# 317       False      False         True  [0, 0, 0, 1]
# 318       False      False         True  [0, 0, 0, 1]
# 319       False      False         True  [0, 0, 0, 1]
# 320       False      False         True  [0, 0, 0, 1]
#
# [382 rows x 7 columns]

# %% [markdown]
# **Write to CSV**

# %%
nw_df.to_csv("guinea_nw.csv", index=False)
ne_df.to_csv("guinea_ne.csv", index=False)
