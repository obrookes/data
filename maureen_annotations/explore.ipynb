# %%
import os
import json
import shutil
import pandas as pd
import numpy as np
from glob import glob
from tqdm import tqdm
import matplotlib.pyplot as plt
import random, math

# %%
csv_files = glob('data/sites/csv/**/*.csv', recursive=True)
sorted_csv_files = sorted(csv_files, key=lambda x: x.split('/')[-1])
initialiser, remainder = sorted_csv_files[0], sorted_csv_files[1:]
df = pd.read_csv(initialiser, encoding="ISO-8859-1")
for file in remainder:
    site = pd.read_csv(file, encoding="ISO-8859-1")
    df = pd.concat([df, site])
df['subdir_video'] = df.subfolder.astype(str) + '_' + df.video_file_name.astype(str)

# %%
df[df.behavioral_context=='camera reaction'].country.value_counts()
# Out:
# gabon           435
# guinea          178
# cotedivoire     166
# nigeria         122
# senegal         118
# drc             106
# uganda           88
# cameroon         78
# rcongo           73
# guineabissau     70
# sierraleone      36
# mali             32
# rwanda           19
# liberia          15
# Name: country, dtype: int64

# %%
df[df.camera_reaction=='yes']
# Out:
#       new_row_id   country research_site genus                     species  \
# 5              6      mali        bafing   Pan           troglodytes verus
# 7              8      mali        bafing   Pan           troglodytes verus
# 12            13      mali        bafing   Pan           troglodytes verus
# 25            26      mali        bafing   Pan           troglodytes verus
# 28            29      mali        bafing   Pan           troglodytes verus
# ...          ...       ...           ...   ...                         ...
# 1317        1318  tanzania   ugalla_issa   Pan  troglodytes schweinfurthii
# 1323        1324  tanzania   ugalla_issa   Pan  troglodytes schweinfurthii
# 1324        1325  tanzania   ugalla_issa   Pan  troglodytes schweinfurthii
# 1326        1327  tanzania   ugalla_issa   Pan  troglodytes schweinfurthii
# 1328        1329  tanzania   ugalla_issa   Pan  troglodytes schweinfurthii
#
#       cam_coverage_area        location_metadata          habitat utm_zone  \
# 5                 14.00  feeding site/fruit tree   gallery forest      29n
# 7                 14.00  feeding site/fruit tree   gallery forest      29n
# 12                 7.00             water source   forest on rock      29n
# 25                12.25             nesting site  forest - bamboo      29n
# 28                12.25             nesting site  forest - bamboo      29n
# ...                 ...                      ...              ...      ...
# 1317                NaN                    trail   gallery forest      36s
# 1323                NaN                    trail   gallery forest      36s
# 1324                NaN                    trail   gallery forest      36s
# 1326                NaN                    trail   gallery forest      36s
# 1328                NaN                    trail   gallery forest      36s
#
#       utm_long  ...      sex tool_use vocalization  bipedal camera_reaction  \
# 5     346467.0  ...     male       no           no       no             yes
# 7     346467.0  ...  unclear       no           no       no             yes
# 12    343264.0  ...   female       no          yes       no             yes
# 25    345234.0  ...  unclear       no           no       no             yes
# 28    345234.0  ...   female       no           no       no             yes
# ...        ...  ...      ...      ...          ...      ...             ...
# 1317  231634.0  ...   female       no           no       no             yes
# 1323  231634.0  ...  unclear       no           no       no             yes
# 1324  231634.0  ...   female       no    offscreen       no             yes
# 1326  231634.0  ...  unclear       no    offscreen       no             yes
# 1328  231634.0  ...  unclear       no           no       no             yes
#
#       behavioral_context  other_species  \
# 5                feeding            NaN
# 7               climbing            NaN
# 12               resting            NaN
# 25                travel            NaN
# 28                travel            NaN
# ...                  ...            ...
# 1317              travel            NaN
# 1323              travel            NaN
# 1324              travel            NaN
# 1326              travel            NaN
# 1328              travel            NaN
#
#                                     additional_comments  record_type  \
# 5            Near the camera, with a fruit in his mouth    60s_video
# 7                          Someone is moving the camera    60s_video
# 12    At the top right side of the screen. Seems to ...    60s_video
# 25           First secs, looking the camera, disappears    60s_video
# 28        Carries an infant ventrally, follows the male    60s_video
# ...                                                 ...          ...
# 1317                                                NaN    60s_video
# 1323                                                NaN    60s_video
# 1324                                     ventral infant    60s_video
# 1326                                                NaN    60s_video
# 1328                             only partially visible    60s_video
#
#                                      subdir_video
# 5     baf_vid10_0346467_1436892_20151112_11280025
# 7      baf_vid10_0346467_1436892_20151227_1030007
# 12    baf_vid11_0343264_1434832_20151019_12100066
# 25    baf_vid12_0345234_1438195_20151123_11280008
# 28    baf_vid12_0345234_1438195_20151123_11280008
# ...                                           ...
# 1317  uga_vidba4_231634_9390066_20141027_ek000027
# 1323  uga_vidba4_231634_9390066_20141027_ek000056
# 1324  uga_vidba4_231634_9390066_20141027_ek000060
# 1326  uga_vidba4_231634_9390066_20141027_ek000060
# 1328  uga_vidba4_231634_9390066_20141027_ek000069
#
# [10154 rows x 37 columns]

# %%
df.behavioral_context.unique()
# Out:
# array(['travel', 'feeding', 'climbing', 'camera reaction', 'resting',
#        'displaying', 'greeting', 'unclear', 'sexual', 'grooming',
#        'tool use termites', 'aggression', 'playing', 'tool use',
#        'reassurance', 'tool use algae', nan, 'tool use unknown',
#        'tool use stone throwing', 'tool use ants', 'tool use honey',
#        'tool use nuts', 'displaying ', 'no'], dtype=object)

# %%
df.head()
# Out:
#    new_row_id country research_site genus            species  \
# 0           1    mali        bafing   Pan  troglodytes verus
# 1           2    mali        bafing   Pan  troglodytes verus
# 2           3    mali        bafing   Pan  troglodytes verus
# 3           4    mali        bafing   Pan  troglodytes verus
# 4           5    mali        bafing   Pan  troglodytes verus
#
#    cam_coverage_area location_metadata            habitat utm_zone  utm_long  \
# 0               9.87             trail     forest on rock      29n  342661.0
# 1              14.00      nesting site  savannah - wooded      29n  344126.0
# 2              14.00      nesting site  savannah - wooded      29n  344126.0
# 3              14.00      nesting site  savannah - wooded      29n  344126.0
# 4              14.00      nesting site  savannah - wooded      29n  344126.0
#
#    ...      sex tool_use vocalization  bipedal camera_reaction  \
# 0  ...     male       no           no       no              no
# 1  ...   female       no           no       no              no
# 2  ...  unclear       no           no       no              no
# 3  ...  unclear       no           no       no              no
# 4  ...   female       no           no       no              no
#
#    behavioral_context  other_species  \
# 0              travel            NaN
# 1             feeding            NaN
# 2             feeding            NaN
# 3             feeding            NaN
# 4             feeding            NaN
#
#                                  additional_comments  record_type  \
# 0                              Not very clear screen    60s_video
# 1             Gray back, disappears at the left side    60s_video
# 2     Follows the above chimp, probably child of her    60s_video
# 3  On the ground, stands near next chimp, and the...    60s_video
# 4  Behind the tree, picks a baobab´s fruit and th...    60s_video
#
#                                  subdir_video
# 0  baf_vid1_0342661_1432807_20141103_11160014
# 1   baf_vid1_0344126_1437042_20151226_1020010
# 2   baf_vid1_0344126_1437042_20151226_1020010
# 3   baf_vid1_0344126_1437042_20151226_1020010
# 4   baf_vid1_0344126_1437042_20151226_1020010
#
# [5 rows x 37 columns]

# %% [markdown]
# **Environment**

# %%
df[df.research_site=='dindefelo'].habitat.value_counts()
# Out:
# gallery forest                        3813
# forest - mixed, open understorey      1943
# rocks                                 1032
# forest - mixed, closed understorey     673
# forest - lianas                        102
# savannah - wooded                       50
# forest - monodominant                   20
# Name: habitat, dtype: int64
