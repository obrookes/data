# %%
import os
import json
import shutil
import pandas as pd
import numpy as np
from glob import glob
from tqdm import tqdm
import matplotlib.pyplot as plt
import random, math

# %%
# Load Maureens annotations
csv_files = glob('data/sites/csv/**/*.csv', recursive=True)
sorted_csv_files = sorted(csv_files, key=lambda x: x.split('/')[-1])
initialiser, remainder = sorted_csv_files[0], sorted_csv_files[1:]
df = pd.read_csv(initialiser, encoding="ISO-8859-1")
for file in remainder:
    site = pd.read_csv(file, encoding="ISO-8859-1")
    df = pd.concat([df, site])
    
df['subdir_video'] = df.subfolder.astype(str) + '_' + df.video_file_name.astype(str)
df.subdir_video = df.subdir_video.apply(lambda x: x.lower())
df.subdir_video = df.subdir_video.str.split('.').str[0]
df['prepend_zero'] = df.subdir_video.apply(lambda x: f'{"_".join(x.split("_")[:-1])}_{"0" + x.split("_")[-1]}')

# %%
# Load filepaths from Jade2
jf = pd.read_csv('data/jade2/chimp_videos.csv', index_col=False)
jf.drop(columns=['Unnamed: 0'], inplace=True)
jf.files = jf.files.apply(lambda x: x.split('.')[0].lower())

# %% [markdown]
# **Matching video-annotations**

# %%
matching1 = df[df.subdir_video.isin(jf.files.values)]
matching1.subdir_video.unique().__len__()
# Out:
# 13460

# %%
# Handling missing zeros
matching2 = df[df.prepend_zero.isin(jf.files.values)]
matching2.drop(columns=['subdir_video'], inplace=True)
matching2.rename(columns={"prepend_zero": "subdir_video"}, inplace=True)
# Out:
# <ipython-input-5-1a0adc9cd001>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching2.drop(columns=['subdir_video'], inplace=True)
# <ipython-input-5-1a0adc9cd001>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching2.rename(columns={"prepend_zero": "subdir_video"}, inplace=True)

# %%
# Concatenate matching dataframes
multi_label_df = pd.concat([matching1, matching2])
multi_label_df.drop(columns=['prepend_zero'], inplace=True)
multi_label_df[multi_label_df.subdir_video.isin(jf.files)]
# Out:
#      new_row_id country research_site genus            species  \
# 0             1    mali        bafing   Pan  troglodytes verus
# 5             6    mali        bafing   Pan  troglodytes verus
# 10           11    mali        bafing   Pan  troglodytes verus
# 11           12    mali        bafing   Pan  troglodytes verus
# 12           13    mali        bafing   Pan  troglodytes verus
# ..          ...     ...           ...   ...                ...
# 963         964  guinea        sobory   Pan  troglodytes verus
# 964         965  guinea        sobory   Pan  troglodytes verus
# 965         966  guinea        sobory   Pan  troglodytes verus
# 966         967  guinea        sobory   Pan  troglodytes verus
# 967         968  guinea        sobory   Pan  troglodytes verus
#
#      cam_coverage_area        location_metadata         habitat utm_zone  \
# 0                 9.87                    trail  forest on rock      29n
# 5                14.00  feeding site/fruit tree  gallery forest      29n
# 10                7.00             water source  forest on rock      29n
# 11                7.00             water source  forest on rock      29n
# 12                7.00             water source  forest on rock      29n
# ..                 ...                      ...             ...      ...
# 963              80.00                    trail  gallery forest      29n
# 964              80.00                    trail  gallery forest      29n
# 965              80.00                    trail  gallery forest      29n
# 966              80.00                    trail  gallery forest      29n
# 967              80.00                    trail  gallery forest      29n
#
#      utm_long  ...      sex tool_use vocalization  bipedal camera_reaction  \
# 0    342661.0  ...     male       no           no       no              no
# 5    346467.0  ...     male       no           no       no             yes
# 10   343264.0  ...   female       no           no       no              no
# 11   343264.0  ...  unclear       no           no       no              no
# 12   343264.0  ...   female       no          yes       no             yes
# ..        ...  ...      ...      ...          ...      ...             ...
# 963  255619.0  ...     male       no           no       no              no
# 964  255619.0  ...  unclear       no           no       no             yes
# 965  255619.0  ...     male       no           no       no             yes
# 966  255619.0  ...     male       no           no       no             yes
# 967  255619.0  ...     male       no           no       no             yes
#
#      behavioral_context  other_species  \
# 0                travel            NaN
# 5               feeding            NaN
# 10              resting            NaN
# 11              resting            NaN
# 12              resting            NaN
# ..                  ...            ...
# 963              travel            NaN
# 964              travel            NaN
# 965              travel            NaN
# 966              travel            NaN
# 967              travel            NaN
#
#                                    additional_comments  record_type  \
# 0                                Not very clear screen    60s_video
# 5           Near the camera, with a fruit in his mouth    60s_video
# 10                         Carries an infant ventrally    60s_video
# 11                  Rides ventrally on the above chimp    60s_video
# 12   At the top right side of the screen. Seems to ...    60s_video
# ..                                                 ...          ...
# 963                                                NaN    60s_video
# 964                                                NaN    60s_video
# 965                                                NaN    60s_video
# 966                                                NaN    60s_video
# 967                                                NaN    60s_video
#
#                                     subdir_video
# 0     baf_vid1_0342661_1432807_20141103_11160014
# 5    baf_vid10_0346467_1436892_20151112_11280025
# 10   baf_vid11_0343264_1434832_20151019_12100066
# 11   baf_vid11_0343264_1434832_20151019_12100066
# 12   baf_vid11_0343264_1434832_20151019_12100066
# ..                                           ...
# 963  sob_vid05_0255619_1305651_20160319_03220020
# 964  sob_vid05_0255619_1305651_20160319_03220020
# 965  sob_vid05_0255619_1305651_20160319_03220020
# 966  sob_vid05_0255619_1305651_20160319_03220020
# 967  sob_vid05_0255619_1305651_20160319_03220020
#
# [42197 rows x 37 columns]

# %%
# Ventral and dorsal carrying
multi_label_df['ventral'] = multi_label_df.additional_comments.apply(lambda x: 1 if 'ventral' in str(x) else 0)
multi_label_df['dorsal'] = multi_label_df.additional_comments.apply(lambda x: 1 if 'dorsal' in str(x) else 0)
multi_label_df['carry'] = multi_label_df.additional_comments.apply(lambda x: 1 if 'carry' in str(x) else 0)
multi_label_df['carries'] = multi_label_df.additional_comments.apply(lambda x: 1 if 'carries' in str(x) else 0)

# %%
multi_label_df['walking'] = multi_label_df.additional_comments.apply(lambda x: 1 if 'walk' in str(x) else 0)
multi_label_df['run'] = multi_label_df.additional_comments.apply(lambda x: 1 if 'run' in str(x) else 0)
multi_label_df['jump'] = multi_label_df.additional_comments.apply(lambda x: 1 if 'jump' in str(x) else 0)
multi_label_df['sit'] = multi_label_df.additional_comments.apply(lambda x: 1 if 'sit' in str(x) else 0)
multi_label_df['hang'] = multi_label_df.additional_comments.apply(lambda x: 1 if 'hang' in str(x) else 0)

# %%
multi_label_df['camera'] = multi_label_df.additional_comments.apply(lambda x: 1 if 'camera' in str(x) else 0)
multi_label_df['look'] = multi_label_df.additional_comments.apply(lambda x: 1 if 'look' in str(x) else 0)
multi_label_df['camera_touch'] = multi_label_df.additional_comments.apply(lambda x: 1 if 'camtouch' in str(x) else 0)
multi_label_df['touch'] = multi_label_df.additional_comments.apply(lambda x: 1 if 'touch' in str(x) else 0)

# %%
multi_label_df['social'] = multi_label_df.additional_comments.apply(lambda x: 1 if 'social' in str(x) else 0)
multi_label_df['play'] = multi_label_df.additional_comments.apply(lambda x: 1 if 'play' in str(x) else 0)
multi_label_df['interaction'] = multi_label_df.additional_comments.apply(lambda x: 1 if 'interaction' in str(x) else 0)

# %%
multi_label_df[(multi_label_df.behavioral_context=='camera reaction')]
# Out:
#       new_row_id       country research_site genus            species  \
# 2171        2172  guineabissau           boe   Pan  troglodytes verus
# 2188        2189  guineabissau           boe   Pan  troglodytes verus
# 2189        2190  guineabissau           boe   Pan  troglodytes verus
# 2190        2191  guineabissau           boe   Pan  troglodytes verus
#
#       cam_coverage_area location_metadata         habitat utm_zone  utm_long  \
# 2171              26.25     buttress tree  gallery forest      28n  618587.0
# 2188              26.25     buttress tree  gallery forest      28n  618587.0
# 2189              26.25     buttress tree  gallery forest      28n  618587.0
# 2190              26.25     buttress tree  gallery forest      28n  618587.0
#
#       ...  jump sit hang  camera look  camera_touch  touch  social  play  \
# 2171  ...     0   0    0       0    0             1      1       0     0
# 2188  ...     0   0    0       0    0             1      1       0     0
# 2189  ...     0   0    0       0    0             1      1       0     0
# 2190  ...     0   0    0       0    0             1      1       0     0
#
#       interaction
# 2171            0
# 2188            0
# 2189            0
# 2190            0
#
# [4 rows x 53 columns]

# %%
multi_label_df.drop_duplicates(subset=['additional_comments']).to_csv('processing_additional_comments.csv')

# %%
# Processing comments
multi_label_df.drop(columns=['utm_zone', 'utm_long', 'utm_lat'], inplace=True)
multi_label_df.to_csv('processing_additional_comments.csv')

# %%
multi_label_df[multi_label_df.subdir_video=='fouta_vid18b_260760_1292882_20140524_pict0122'][['behavioral_context','additional_comments']]
# Out:
#      behavioral_context                                additional_comments
# 2739         displaying  **This video has a lot going on so I attempted...
# 2740         displaying                                     ventral infant
# 2741         displaying  2nd to far right at beginning; has a dorsal in...
# 2742         displaying                    dorsal infant with female above
# 2743         displaying                    following not far behind female
# 2744         displaying  following behind juvenile above; goes downhill...
# 2745         displaying  following behind other 2 juveniles; crutch wal...
# 2746         displaying        following behind juvs; has a ventral infant
# 2747         displaying                                     ventral infant
# 2748         displaying              in background behind the adult female
# 2749         displaying  adolescent or young adult; full swelling, nipp...
# 2750         displaying              following behind the adult male above
# 2751         displaying  traveling past behind the adult female with ma...
# 2752         displaying  climbs low into tree while the adult female ab...
# 2753         displaying    moving in background; first visible around 0:37
# 2754         displaying  traveling near male above, in background; head...
# 2755         displaying  seen moving in background foliage center right...
# 2756         displaying  seen moving in background foliage center right...
# 2757         displaying  also background left in foliage, a bit later, ...
# 2758         displaying  first appears around 0:12; swaggers toward mal...
# 2759         displaying  climbs up tree behind and to left of adolescen...
# 2760         displaying  first visible sitting down at 0:38 at center b...
# 2761         displaying                                      dorsal infant
# 2762         displaying    displays around 0:30, then sits on rock at 0:51
# 2763         displaying               sits on rock background left at 0:33
# 2764         displaying  right behind/to the left of juvenile in the ro...
# 2765         displaying  right behind the displaying male at 0:42; has ...
# 2766         displaying                                     ventral infant
# 2767         displaying      right behind female with ventral infant above
# 2768         displaying  behind the adult female with ventral infant 3 ...
# 2769         displaying                                     ventral infant
# 2770         displaying  first visible background left at ~0:44; has a ...
# 2771         displaying                                      dorsal infant
# 2772         displaying  appears behind female with dorsal infant 2 row...
# 2773         displaying                                     ventral infant
# 2774         displaying                     behind the female 2 rows above
# 2775         displaying  behind the juvenile in row above; just to left...
# 2776         displaying               sits on rock background left at 0:55
# 2777         displaying       seen in front of female 2 rows above at 0:53
# 2778         displaying   swinging above in trees in last seconds of video
# 2779         displaying  visible as next chimp to left of the adult mal...
# 2780         displaying  visible at ~0:54 behind the adolescent male wh...
# 2781         displaying  visible in last frame, far left back, gives a ...
# 2782         displaying  barely visible on far left in last second; onl...

# %%
# Trial 
test = multi_label_df
test = test.loc[:, ['subdir_video','behavioral_context']]

# %%
test

# %%
test = test.set_index('subdir_video').dropna(axis=1, how='all')
test = pd.get_dummies(test, prefix='', prefix_sep='').groupby(level=0, axis=1).max()
test = test.reset_index('subdir_video').dropna(axis=1, how='all')

# %%
test

# %%
test['count'] = test.loc[:, test.columns != 'subdir_video'].sum(axis=1)

# %%
test.subdir_video.unique().__len__()
