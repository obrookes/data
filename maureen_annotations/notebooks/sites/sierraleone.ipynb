# %%
import json
import shutil
import pandas as pd
import numpy as np
from glob import glob
from tqdm import tqdm

# %%
df = pd.read_csv('sites/outamba_chimp_video_data.csv', encoding = "ISO-8859-1")

# %%
df.columns
# Out:
# Index(['new_row_id', 'country', 'research_site', 'genus', 'species',
#        'cam_coverage_area', 'location_metadata', 'habitat', 'utm_zone',
#        'utm_long', 'utm_lat', 'cam_id', 'vid_res', 'vid_duration',
#        'panaf_datasheet_comments', 'year', 'month', 'day', 'time_hr',
#        'time_min', 'cell_id', 'subfolder', 'video_file_name', 'event_id',
#        'min_number_chimps_per_video', 'max_number_chimps_per_video',
#        'age_class', 'sex', 'tool_use', 'vocalization', 'bipedal',
#        'camera_reaction', 'behavioral_context', 'other_species',
#        'additional_comments', 'record_type'],
#       dtype='object')

# %%
df.subfolder
# Out:
# 0      oknp_vid10_0809778_1073360_20170203
# 1      oknp_vid10_0809778_1073360_20170203
# 2      oknp_vid10_0809778_1073360_20170203
# 3      oknp_vid10_0809778_1073360_20170203
# 4      oknp_vid10_0809778_1073360_20170203
#                       ...
# 800    oknp_vid35_0812974_1070572_20170719
# 801    oknp_vid13_0811174_1071658_20170811
# 802    oknp_vid13_0811174_1071658_20170811
# 803    oknp_vid13_0811174_1071658_20170811
# 804    oknp_vid13_0811174_1071658_20170811
# Name: subfolder, Length: 805, dtype: object

# %%
df.video_file_name
# Out:
# 0      2120079
# 1      2120079
# 2      2120080
# 3      2120081
# 4      2120081
#         ...
# 800    7260070
# 801    8240058
# 802    8240058
# 803    8240058
# 804    8240059
# Name: video_file_name, Length: 805, dtype: int64

# %%
df.video_file_name[0]
# Out:
# numpy.int64

# %%
df['subdir_video'] = df['subfolder'] + '_' + df['video_file_name'].apply(lambda x: str(x))
df['subdir_video'] = df['subdir_video'].str.lower()

df['subdir_video_0'] = df.subdir_video.str.split('_').str[:5] + pd.Series('0' + df.subdir_video.str.split('_').str[5]).apply(lambda x: [x])
df['subdir_video_0'] = df['subdir_video_0'].str.join('_') 

# Only videos with 1 ape
df = df[df.max_number_chimps_per_video==1]
len(df)
# Out:
# 151

# %%
# What we have locally
local_filenames = glob('/home/dl18206/Desktop/phd/data/panaf/chimp_videos/sierraleone/**/*.mp4', recursive=True)
local_filenames = [x.split('/')[-2:] for x in local_filenames]
local_filenames = [x[-1].split('.')[0].lower() for x in local_filenames]

# %%
df[df.subdir_video.isin(local_filenames)].behavioral_context.value_counts().sum()
df[df.subdir_video_0.isin(local_filenames)].behavioral_context.value_counts().sum()
print(f"Total: {df[df.subdir_video.isin(local_filenames)].behavioral_context.value_counts().sum() + df[df.subdir_video_0.isin(local_filenames)].behavioral_context.value_counts().sum()}")
# Out:
# Total: 130

# %%
# Don't have...
df[~df.subdir_video_0.isin(local_filenames) & ~df.subdir_video.isin(local_filenames)]
# Out:
#      new_row_id      country research_site genus            species  \
# 118         119  sierraleone       outamba   Pan  troglodytes verus
# 214         215  sierraleone       outamba   Pan  troglodytes verus
# 237         238  sierraleone       outamba   Pan  troglodytes verus
# 264         265  sierraleone       outamba   Pan  troglodytes verus
# 265         266  sierraleone       outamba   Pan  troglodytes verus
# 266         267  sierraleone       outamba   Pan  troglodytes verus
# 405         406  sierraleone       outamba   Pan  troglodytes verus
# 442         443  sierraleone       outamba   Pan  troglodytes verus
# 462         463  sierraleone       outamba   Pan  troglodytes verus
# 464         465  sierraleone       outamba   Pan  troglodytes verus
# 465         466  sierraleone       outamba   Pan  troglodytes verus
# 575         576  sierraleone       outamba   Pan  troglodytes verus
# 577         578  sierraleone       outamba   Pan  troglodytes verus
# 598         599  sierraleone       outamba   Pan  troglodytes verus
# 640         641  sierraleone       outamba   Pan  troglodytes verus
# 644         645  sierraleone       outamba   Pan  troglodytes verus
# 660         661  sierraleone       outamba   Pan  troglodytes verus
# 662         663  sierraleone       outamba   Pan  troglodytes verus
# 663         664  sierraleone       outamba   Pan  troglodytes verus
# 671         672  sierraleone       outamba   Pan  troglodytes verus
# 687         688  sierraleone       outamba   Pan  troglodytes verus
#
#      cam_coverage_area          location_metadata         habitat utm_zone  \
# 118                NaN                 ceiba tree  gallery forest      28n
# 214                NaN                      trail  gallery forest      28n
# 237                NaN               water source  gallery forest      28n
# 264                NaN                      trail  gallery forest      28n
# 265                NaN         water source/trail  gallery forest      28n
# 266                NaN         water source/trail  gallery forest      28n
# 405                NaN                 ceiba tree  gallery forest      28n
# 442                NaN                 ceiba tree  gallery forest      28n
# 462                NaN               water source  gallery forest      28n
# 464                NaN               water source  gallery forest      28n
# 465                NaN               water source  gallery forest      28n
# 575                NaN               water source  gallery forest      28n
# 577                NaN               water source  gallery forest      28n
# 598                NaN  feeding site/water source  gallery forest      28n
# 640                NaN               water source  gallery forest      28n
# 644                NaN               water source  gallery forest      28n
# 660                NaN                      trail  gallery forest      28n
# 662                NaN                      trail  gallery forest      28n
# 663                NaN                      trail  gallery forest      28n
# 671                NaN                      trail  gallery forest      28n
# 687                NaN                      trail  gallery forest      28n
#
#      utm_long  ...  tool_use  vocalization bipedal  camera_reaction  \
# 118    811323  ...        no            no      no              yes
# 214    810755  ...        no            no      no               no
# 237    811052  ...       yes            no     yes               no
# 264    811174  ...        no            no      no               no
# 265    811261  ...        no            no      no               no
# 266    811261  ...        no            no      no               no
# 405    811354  ...        no            no      no               no
# 442    811354  ...        no            no      no               no
# 462    811056  ...       yes            no      no               no
# 464    811056  ...       yes            no      no               no
# 465    811056  ...       yes            no      no               no
# 575    811056  ...       yes            no      no               no
# 577    811056  ...       yes            no      no               no
# 598    811962  ...        no     offscreen      no               no
# 640    811916  ...        no            no      no               no
# 644    811871  ...        no            no      no               no
# 660    813345  ...        no            no      no              yes
# 662    813345  ...        no            no      no               no
# 663    813345  ...        no            no      no              yes
# 671    813345  ...        no            no      no               no
# 687    813345  ...        no            no      no               no
#
#     behavioral_context  other_species    additional_comments  \
# 118    camera reaction            NaN      camera inspection
# 214             travel            NaN  just the back visible
# 237     tool use algae            NaN         fishing algaes
# 264           climbing            NaN                running
# 265             travel            NaN                    NaN
# 266             travel            NaN                    NaN
# 405             travel            NaN                    NaN
# 442             travel            NaN    corrected timestamp
# 462     tool use algae            NaN          fishing algae
